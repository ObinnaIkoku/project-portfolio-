# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('general_data.csv')

# %%
df.head(10)
# Out:
#    Age Attrition              Department  DistanceFromHome EducationField  \
# 0   51        No                   Sales                 6  Life Sciences
# 1   31       Yes  Research & Development                10  Life Sciences
# 2   32        No  Research & Development                17          Other
# 3   38        No  Research & Development                 2  Life Sciences
# 4   32        No  Research & Development                10        Medical
# 5   46        No  Research & Development                 8  Life Sciences
# 6   28       Yes  Research & Development                11        Medical
# 7   29        No  Research & Development                18  Life Sciences
# 8   31        No  Research & Development                 1  Life Sciences
# 9   25        No  Research & Development                 7        Medical
#
#    EmployeeID  Gender  JobLevel                    JobRole MaritalStatus  \
# 0           1  Female         1  Healthcare Representative       Married
# ...

# %%
df.shape
# Out:
# (4410, 19)

# %%
#funtion to drop null values from rows and columns; for data cleaning 
df1 = df.dropna()

# %%
df1.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# Department                 0
# DistanceFromHome           0
# EducationField             0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df1.head(10)
# Out:
#    Age Attrition              Department  DistanceFromHome EducationField  \
# 0   51        No                   Sales                 6  Life Sciences
# 1   31       Yes  Research & Development                10  Life Sciences
# 2   32        No  Research & Development                17          Other
# 3   38        No  Research & Development                 2  Life Sciences
# 4   32        No  Research & Development                10        Medical
# 5   46        No  Research & Development                 8  Life Sciences
# 6   28       Yes  Research & Development                11        Medical
# 7   29        No  Research & Development                18  Life Sciences
# 8   31        No  Research & Development                 1  Life Sciences
# 9   25        No  Research & Development                 7        Medical
#
#    EmployeeID  Gender  JobLevel                    JobRole MaritalStatus  \
# 0           1  Female         1  Healthcare Representative       Married
# ...

# %%
#count of employees that stayed and left 
df1['Attrition'].value_counts()
# Out:
# No     3677
# Yes     705
# Name: Attrition, dtype: int64

# %%
df1.describe()
# Out:
#                Age  DistanceFromHome   EmployeeID     JobLevel  MonthlyIncome  \
# count  4382.000000       4382.000000  4382.000000  4382.000000    4382.000000
# mean     36.933364          9.198996  2207.804884     2.063898   65061.702419
# std       9.137272          8.105396  1271.688783     1.106115   47142.310175
# min      18.000000          1.000000     1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000  1108.250000     1.000000   29110.000000
# 50%      36.000000          7.000000  2208.500000     2.000000   49190.000000
# 75%      43.000000         14.000000  3308.750000     3.000000   83790.000000
# max      60.000000         29.000000  4409.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count         4382.000000        4382.000000       4382.000000
# mean             2.693291          15.210634          0.794614
# std              2.497832           3.663007          0.852397
# ...

# %%
#visualise attitition data 
sns.countplot(df1['Attrition'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
(3677 - 705) / 3677
# Out:
# 0.8082676094642371

# %%
#number of employee's that left or stayed based on age 
plt.subplots(figsize = (12,4))
sns.countplot(x='Age', hue = 'Attrition', data = df1, palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.subplots(figsize = (12,4))
sns.countplot(x='Gender', hue = 'Attrition', data = df1, palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#print all of object data types and their unique values 
for column in df1.columns: 
    if df1[column].dtype == object:
        print(str(column) + ' : ' + str(df1[column].unique()))
        print(df[column].value_counts())
        print('_______________________________________________')
# Out:
# Attrition : ['No' 'Yes']
# No     3699
# Yes     711
# Name: Attrition, dtype: int64
# _______________________________________________
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    2883
# Sales                     1338
# Human Resources            189
# Name: Department, dtype: int64
# _______________________________________________
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       1818
# Medical             1392
# Marketing            477
# Technical Degree     396
# Other                246
# Human Resources       81
# Name: EducationField, dtype: int64
# _______________________________________________
# Gender : ['Female' 'Male']
# Male      2646
# Female    1764
# Name: Gender, dtype: int64
# _______________________________________________
# JobRole : ['Healthcare Representative' 'Research Scientist' 'Sales Executive'
# ...

# %%
#visualise the correlation 
plt.figure(figsize = (16, 7))
sns.heatmap(df.corr(), annot = True, fmt = '.0%')
# Out:
# <AxesSubplot:>

# %%
#tranform non-numerical data in numerical column
from sklearn.preprocessing import LabelEncoder

for column in df1.columns:
        if df1[column].dtype == np.number:
            continue
        df1[column] = LabelEncoder().fit_transform(df1[column])
# Out:
# <ipython-input-19-e0e2c4d26ebc>:5: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df1[column].dtype == np.number:
# <ipython-input-19-e0e2c4d26ebc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[column] = LabelEncoder().fit_transform(df1[column])

# %%
#Creat new column 
df1['Age_Year'] = df1['Age']
# Out:
# <ipython-input-20-11f83d477a42>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Age_Year'] = df1['Age']

# %%
#drop age column
df1 = df1.drop('Age', axis = 1)

# %%
df1
# Out:
#       Attrition  Department  DistanceFromHome  EducationField  EmployeeID  \
# 0             0           2                 5               1           0
# 1             1           1                 9               1           1
# 2             0           1                16               4           2
# 3             0           1                 1               1           3
# 4             0           1                 9               3           4
# ...         ...         ...               ...             ...         ...
# 4404          0           2                 3               4        4377
# 4405          0           1                 4               3        4378
# 4406          0           1                 1               3        4379
# 4407          0           1                24               1        4380
# 4408          0           2                17               3        4381
#
#       Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  \
# ...

# %%
 #Split the data into independent 'X' and dependent 'Y' variables
X = df1.iloc[:, 1:df.shape[1]].values 
Y = df1.iloc[:, 0].values

# %%
# Split the dataset into 75% Training set and 25% Testing set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
#Use Random Forest Classification algorithm
    
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
#Get the accuracy on the training data
forest.score(X_train, Y_train)
# Out:
# 0.9972611077297626

# %%
#Show the confusion matrix and accuracy for  the model on the test data
#Classification accuracy is the ratio of correct predictions to total predictions made.
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, forest.predict(X_test))
  
TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]
  
print(cm)
print('Model Testing Accuracy = "{}!"'.format(  (TP + TN) / (TP + TN + FN + FP)))
print()# Print a new line
# Out:
# [[888   1]
#  [ 40 167]]
# Model Testing Accuracy = "0.9625912408759124!"

# %%
# Return the feature importances (the higher, the more important the feature).
importances = pd.DataFrame({'feature':df.iloc[:, 1:df.shape[1]].columns,'importance':np.round(forest.feature_importances_,3)}) #Note: The target column is at position 0
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances
# Out:
#                          importance
# feature
# YearsWithCurrManager          0.112
# MaritalStatus                 0.099
# StockOptionLevel              0.091
# NumCompaniesWorked            0.074
# TrainingTimesLastYear         0.069
# Department                    0.068
# JobLevel                      0.057
# MonthlyIncome                 0.056
# YearsSinceLastPromotion       0.052
# TotalWorkingYears             0.044
# DistanceFromHome              0.044
# JobRole                       0.043
# YearsAtCompany                0.042
# EducationField                0.040
# Gender                        0.036
# PercentSalaryHike             0.033
# Attrition                     0.022
# EmployeeID                    0.017

# %%
#Visualize the importance
importances.plot.bar()
# Out:
# <AxesSubplot:xlabel='feature'>

# %%
from sklearn.linear_model import LogisticRegression
