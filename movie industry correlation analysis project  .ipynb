# %%
# import libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import figure

# %%
df=pd.read_csv('movies.csv') # read in data

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
#checking for null values and data cleaning 
df.isna().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
for col in df.columns:                         #percentage of data missing in each column (view format)
    pct_missing = np.mean(df[col].isnull())
    print('{} - %{}'.format(col, pct_missing))
# Out:
# name - %0.0
# rating - %0.010041731872717789
# genre - %0.0
# year - %0.0
# released - %0.0002608242044861763
# score - %0.0003912363067292645
# votes - %0.0003912363067292645
# director - %0.0
# writer - %0.0003912363067292645
# star - %0.00013041210224308815
# country - %0.0003912363067292645
# budget - %0.2831246739697444
# gross - %0.02464788732394366
# company - %0.002217005738132499
# runtime - %0.0005216484089723526

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df1 = df.dropna()

# %%
df1.isna().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df1 = df1.sort_values(by=['gross'], inplace=False, ascending=False) #format by higest grossing movies

# %%
df1.drop_duplicates()   #further data cleaning: allows us to drop all duplicate rows df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
df1.head(10)
# Out:
#                                             name rating      genre  year  \
# 5445                                      Avatar  PG-13     Action  2009
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 3045                                     Titanic  PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
# 6646                                   Furious 7  PG-13     Action  2015
# 7494                                   Frozen II     PG  Animation  2019
#
#                                released  score      votes         director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0    James Cameron
# ...

# %%
#we begin exporatory analysis with visualisation on movie industry data 
df1.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  5421.000000  5421.000000  5.421000e+03  5.421000e+03  5.421000e+03
# mean   2001.661317     6.392455  1.150661e+05  3.600917e+07  1.032297e+08
# std      10.540908     0.962730  1.844073e+05  4.157337e+07  1.873027e+08
# min    1980.000000     1.900000  1.950000e+02  6.000000e+03  3.090000e+02
# 25%    1993.000000     5.800000  1.900000e+04  1.000000e+07  1.073640e+07
# 50%    2002.000000     6.500000  5.200000e+04  2.180000e+07  3.686941e+07
# 75%    2011.000000     7.100000  1.290000e+05  4.500000e+07  1.124625e+08
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  5421.000000
# mean    108.152739
# std      18.115698
# min      63.000000
# 25%      95.000000
# 50%     105.000000
# 75%     118.000000
# max     271.000000

# %%
#hypothesis : ho = no significant relationaship between gross and budget 
#h1(alt hypo) = significant relationship between gross and budget

# %%
#regression plot budget vs gross using seaborn
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(14, 10.5)
sns.regplot(x='budget', y='gross', data=df1, scatter_kws={"color":"purple"}, line_kws={"color":"black"}).set_title("Budget vs gross")
sns.despine()

# %%
#now to start identifying corrolations: defualt type in IDE is pearson, others include kendall and spearman 
df1.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df1.corr(method = 'kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
df1.corr(method = 'spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
#based on 3 corrolation methods tested(not shown), it can be asserted that gross revenue and movie budget are highly corrolated 
#below are diagrams that eleborate on corrolation between metrics

# %%
correlation_matrix = df1.corr()

plt.figure(figsize = (14, 7))

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating    0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre     0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year      0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released  0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score    -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes     0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director  0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer    0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star      0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country   0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# budget    0.277488  0.193353  0.073008  0.300621  0.285691 -0.012642
# gross     0.947324  0.158582  0.038616  0.980873  0.976423 -0.047041
# ...

# %%
correlation_matrix = df1.apply(lambda x: x.factorize()[0]).corr(method='pearson')

plt.figure(figsize = (14, 7))

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df1.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name     name        1.000000
#          rating      0.314800
#          genre       0.186668
#          year        0.267282
#          released    0.667785
#                        ...
# runtime  country     0.020546
#          budget      0.092727
#          gross       0.088572
#          company     0.069329
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# rating   score     -0.075109
# score    rating    -0.075109
#          country   -0.057087
# country  score     -0.057087
#          genre     -0.055109
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# director  star        0.504992
# star      director    0.504992
# writer    star        0.510628
# star      writer      0.510628
# votes     writer      0.522918
# writer    votes       0.522918
# budget    name        0.526690
# name      budget      0.526690
# director  company     0.528071
# company   director    0.528071
# writer    company     0.532013
# company   writer      0.532013
# budget    gross       0.532810
# gross     budget      0.532810
# released  writer      0.541155
# writer    released    0.541155
# star      name        0.599410
# name      star        0.599410
# votes     name        0.608411
# name      votes       0.608411
# gross     star        0.612142
# star      gross       0.612142
# gross     votes       0.620450
# votes     gross       0.620450
# company   name        0.631721
# name      company     0.631721
# gross     company     0.637241
# company   gross       0.637241
# director  writer      0.642875
# writer    director    0.642875
# ...

# %%
df1['Year'] = df1['released'].astype(str).str[:4]
df1
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# Looking at the top 15 companies by gross revenue
CompanyGrossSum = df1.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Warner Bros.           2005    2688767210
# Name: gross, dtype: int64

# %%
plt.figure(figsize = (14, 7))
plt.scatter(x=df1['budget'], y=df1['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()
